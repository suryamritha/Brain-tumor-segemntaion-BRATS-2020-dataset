# %%
import os
import cv2
import glob
import PIL
import shutil
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from skimage import data
from skimage.util import montage 
import skimage.transform as skTrans
from skimage.transform import rotate
from skimage.transform import resize
from PIL import Image, ImageOps  


# neural imaging
import nilearn as nl
import nibabel as nib
import nilearn.plotting as nlplt



# ml libs
import keras
import keras.backend as K
from keras.callbacks import CSVLogger
import tensorflow as tf
from tensorflow.keras.utils import plot_model
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.layers.experimental import preprocessing


# Make numpy printouts easier to read.
np.set_printoptions(precision=3, suppress=True)

# %%
# DEFINE seg-areas  
SEGMENT_CLASSES = {
    0 : 'NOT tumor',
    1 : 'NECROTIC/CORE', # or NON-ENHANCING tumor CORE
    2 : 'EDEMA',
    3 : 'ENHANCING' # original 4 -> converted into 3 later
}

# there are 155 slices per volume
# to start at 5 and use 145 slices means we will skip the first 5 and last 5 
VOLUME_SLICES = 100 
VOLUME_START_AT = 22 # first slice of volume that we will include

# %%
TRAIN_DATASET_PATH = 'C:/Users/srini/Downloads/archive (1)/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/'
VALIDATION_DATASET_PATH = 'C:/Users/srini/Downloads/archive (1)/BraTS2020_ValidationData/MICCAI_BraTS2020_ValidationData/'

test_image_flair=nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_001/BraTS20_Training_001_flair.nii').get_fdata()
test_image_t1=nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_001/BraTS20_Training_001_t1.nii').get_fdata()
test_image_t1ce=nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_001/BraTS20_Training_001_t1ce.nii').get_fdata()
test_image_t2=nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_001/BraTS20_Training_001_t2.nii').get_fdata()
test_mask=nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_001/BraTS20_Training_001_seg.nii').get_fdata()

fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(1,5, figsize = (20, 10))
slice_w = 25
ax1.imshow(test_image_flair[:,:,test_image_flair.shape[0]//2-slice_w], cmap = 'gray')
ax1.set_title('Image flair')
ax2.imshow(test_image_t1[:,:,test_image_t1.shape[0]//2-slice_w], cmap = 'gray')
ax2.set_title('Image t1')
ax3.imshow(test_image_t1ce[:,:,test_image_t1ce.shape[0]//2-slice_w], cmap = 'gray')
ax3.set_title('Image t1ce')
ax4.imshow(test_image_t2[:,:,test_image_t2.shape[0]//2-slice_w], cmap = 'gray')
ax4.set_title('Image t2')
ax5.imshow(test_mask[:,:,test_mask.shape[0]//2-slice_w])
ax5.set_title('Mask')
# Out:
# Text(0.5, 1.0, 'Mask')

# %%
# Skip 50:-50 slices since there is not much to see
fig, ax1 = plt.subplots(1, 1, figsize = (15,15))
ax1.imshow(rotate(montage(test_image_t1[50:-50,:,:]), 90, resize=True), cmap ='gray')

# %%
# Skip 50:-50 slices since there is not much to see
fig, ax1 = plt.subplots(1, 1, figsize = (15,15))
ax1.imshow(rotate(montage(test_mask[60:-60,:,:]), 90, resize=True), cmap ='gray')

# %%
niimg = nl.image.load_img(TRAIN_DATASET_PATH + 'BraTS20_Training_001/BraTS20_Training_001_flair.nii')
nimask = nl.image.load_img(TRAIN_DATASET_PATH + 'BraTS20_Training_001/BraTS20_Training_001_seg.nii')

fig, axes = plt.subplots(nrows=4, figsize=(30, 40))


nlplt.plot_anat(niimg,
                title='BraTS20_Training_001_flair.nii plot_anat',
                axes=axes[0])

nlplt.plot_epi(niimg,
               title='BraTS20_Training_001_flair.nii plot_epi',
               axes=axes[1])

nlplt.plot_img(niimg,
               title='BraTS20_Training_001_flair.nii plot_img',
               axes=axes[2])

nlplt.plot_roi(nimask, 
               title='BraTS20_Training_001_flair.nii with mask plot_roi',
               bg_img=niimg, 
               axes=axes[3], cmap='Paired')

plt.show()

# %%
# dice loss as defined above for 4 classes
def dice_coef(y_true, y_pred, smooth=1.0):
    class_num = 4
    for i in range(class_num):
        y_true_f = K.flatten(y_true[:,:,:,i])
        y_pred_f = K.flatten(y_pred[:,:,:,i])
        intersection = K.sum(y_true_f * y_pred_f)
        loss = ((2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth))
   #     K.print_tensor(loss, message='loss value for class {} : '.format(SEGMENT_CLASSES[i]))
        if i == 0:
            total_loss = loss
        else:
            total_loss = total_loss + loss
    total_loss = total_loss / class_num
#    K.print_tensor(total_loss, message=' total dice coef: ')
    return total_loss


 
# define per class evaluation of dice coef
# inspired by https://github.com/keras-team/keras/issues/9395
def dice_coef_necrotic(y_true, y_pred, epsilon=1e-6):
    intersection = K.sum(K.abs(y_true[:,:,:,1] * y_pred[:,:,:,1]))
    return (2. * intersection) / (K.sum(K.square(y_true[:,:,:,1])) + K.sum(K.square(y_pred[:,:,:,1])) + epsilon)

def dice_coef_edema(y_true, y_pred, epsilon=1e-6):
    intersection = K.sum(K.abs(y_true[:,:,:,2] * y_pred[:,:,:,2]))
    return (2. * intersection) / (K.sum(K.square(y_true[:,:,:,2])) + K.sum(K.square(y_pred[:,:,:,2])) + epsilon)

def dice_coef_enhancing(y_true, y_pred, epsilon=1e-6):
    intersection = K.sum(K.abs(y_true[:,:,:,3] * y_pred[:,:,:,3]))
    return (2. * intersection) / (K.sum(K.square(y_true[:,:,:,3])) + K.sum(K.square(y_pred[:,:,:,3])) + epsilon)



# Computing Precision 
def precision(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

    
# Computing Sensitivity      
def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())


# Computing Specificity
def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

# %%
IMG_SIZE=128

# %%
# source https://naomi-fridman.medium.com/multi-class-image-segmentation-a5cc671e647a

def build_unet(inputs, ker_init, dropout):
    conv1 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(inputs)
    conv1 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv1)
    pool = MaxPooling2D(pool_size=(2, 2))(conv1)
    
    conv = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool)
    conv = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv)
    
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool1)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv3)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv3)
    
    #deep nested layer
    up1 = Conv2D(32, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(pool1))
    merge1 = concatenate([pool,up1], axis = 3)
    convN1 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge1)

    up2 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(pool2))
    merge2 = concatenate([pool1,up2], axis = 3)
    convN2 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge2)

    up3 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(pool4))
    merge3 = concatenate([pool2,up3], axis = 3)
    convN3 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge3)
      
    up4 = Conv2D(32, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(convN2))
    merge4 = concatenate([pool,up4,convN1], axis = 3)
    convN4 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge4)

    up5 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(convN3))
    merge5 = concatenate([pool1,up5,convN2], axis = 3)
    convN5 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge5)

    up6 = Conv2D(32, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(convN5))
    merge6 = concatenate([up6,convN4,convN1,pool], axis = 3)
    convN6 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge6)

    
    #bottleneck layer
    
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv5 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool4)
    conv5 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv5)
    drop5 = Dropout(dropout)(conv5)
    
    #decoder layer
    up7 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(drop5))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge7)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv7)

    up8 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(conv7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge8)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv8)

    up9 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(conv8))
    merge9 = concatenate([conv,up9], axis = 3)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge9)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv9)
    
    up = Conv2D(32, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(conv9))
    merge = concatenate([conv1,up], axis = 3)
    conv = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge)
    conv = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv)
    
    conv10 = Conv2D(4, (1,1), activation = 'softmax')(conv)
    
    return Model(inputs = inputs, outputs = conv10)

input_layer = Input((IMG_SIZE, IMG_SIZE, 2))

model = build_unet(input_layer, 'he_normal', 0.2)
model.compile(loss="categorical_crossentropy", optimizer=keras.optimizers.Adam(learning_rate=0.001), metrics = ['accuracy',tf.keras.metrics.MeanIoU(num_classes=4), dice_coef, precision, sensitivity, specificity, dice_coef_necrotic, dice_coef_edema ,dice_coef_enhancing] )

# %%
# lists of directories with studies
train_and_val_directories = [f.path for f in os.scandir(TRAIN_DATASET_PATH) if f.is_dir()]

# file BraTS20_Training_355 has ill formatted name for for seg.nii file
train_and_val_directories.remove(TRAIN_DATASET_PATH+'BraTS20_Training_355')


def pathListIntoIds(dirList):
    x = []
    for i in range(0,len(dirList)):
        x.append(dirList[i][dirList[i].rfind('/')+1:])
    return x

train_and_test_ids = pathListIntoIds(train_and_val_directories); 

    
train_test_ids, val_ids = train_test_split(train_and_test_ids,test_size=0.2) 
train_ids, test_ids = train_test_split(train_test_ids,test_size=0.15)

# %%
class DataGenerator(keras.utils.Sequence):
    'Generates data for Keras'
    def __init__(self, list_IDs, dim=(IMG_SIZE,IMG_SIZE), batch_size = 1, n_channels = 2, shuffle=True):
        'Initialization'
        self.dim = dim
        self.batch_size = batch_size
        self.list_IDs = list_IDs
        self.n_channels = n_channels
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        # Find list of IDs
        Batch_ids = [self.list_IDs[k] for k in indexes]

        # Generate data
        X, y = self.__data_generation(Batch_ids)

        return X, y

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __data_generation(self, Batch_ids):
        'Generates data containing batch_size samples' # X : (n_samples, *dim, n_channels)
        # Initialization
        X = np.zeros((self.batch_size*VOLUME_SLICES, *self.dim, self.n_channels))
        y = np.zeros((self.batch_size*VOLUME_SLICES, 240, 240))
        Y = np.zeros((self.batch_size*VOLUME_SLICES, *self.dim, 4))

        
        # Generate data
        for c, i in enumerate(Batch_ids):
            case_path = os.path.join(TRAIN_DATASET_PATH, i)

            data_path = os.path.join(case_path, f'{i}_flair.nii');
            flair = nib.load(data_path).get_fdata()    

            data_path = os.path.join(case_path, f'{i}_t1ce.nii');
            ce = nib.load(data_path).get_fdata()
            
            data_path = os.path.join(case_path, f'{i}_seg.nii');
            seg = nib.load(data_path).get_fdata()
        
            for j in range(VOLUME_SLICES):
                 X[j +VOLUME_SLICES*c,:,:,0] = cv2.resize(flair[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE));
                 X[j +VOLUME_SLICES*c,:,:,1] = cv2.resize(ce[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE));

                 y[j +VOLUME_SLICES*c] = seg[:,:,j+VOLUME_START_AT];
                    
        # Generate masks
        y[y==4] = 3;
        mask = tf.one_hot(y, 4);
        Y = tf.image.resize(mask, (IMG_SIZE, IMG_SIZE));
        return X/np.max(X), Y
        
training_generator = DataGenerator(train_ids)
valid_generator = DataGenerator(val_ids)
test_generator = DataGenerator(test_ids)

# %%
# show number of data for each dir 
def showDataLayout():
    plt.bar(["Train","Valid","Test"],
    [len(train_ids), len(val_ids), len(test_ids)], align='center',color=[ 'green','red', 'blue'])
    plt.legend()

    plt.ylabel('Number of images')
    plt.title('Data distribution')

    plt.show()
    
showDataLayout()

# %%
csv_logger = CSVLogger('training3.log', separator=',', append=False)


callbacks = [
#     keras.callbacks.EarlyStopping(monitor='loss', min_delta=0,
#                               patience=2, verbose=1, mode='auto'),
      keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                              patience=2, min_lr=0.000001, verbose=1),
#  keras.callbacks.ModelCheckpoint(filepath = 'model_.{epoch:02d}-{val_loss:.6f}.m5',
#                             verbose=1, save_best_only=True, save_weights_only = True)
        csv_logger
    ]

# %%
K.clear_session()
history =  model.fit(training_generator,
                     epochs=35,
                     steps_per_epoch=len(train_ids),
                     callbacks= callbacks,
                     validation_data = valid_generator
                     )  
model.save("model_run3.h5")
# Out:
# Epoch 1/35
# 2023-10-15 16:04:49.048384: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 249/249 [==============================] - 268s 976ms/step - loss: 0.1728 - accuracy: 0.9796 - mean_io_u: 0.6403 - dice_coef: 0.2677 - precision: 0.9785 - sensitivity: 0.9598 - specificity: 0.9947 - dice_coef_necrotic: 0.0650 - dice_coef_edema: 0.1253 - dice_coef_enhancing: 0.0462 - val_loss: 0.0797 - val_accuracy: 0.9820 - val_mean_io_u: 0.8280 - val_dice_coef: 0.2711 - val_precision: 0.9819 - val_sensitivity: 0.9819 - val_specificity: 0.9940 - val_dice_coef_necrotic: 0.0460 - val_dice_coef_edema: 0.1470 - val_dice_coef_enhancing: 0.0170 - lr: 0.0010
# Epoch 2/35
# 249/249 [==============================] - 260s 1s/step - loss: 0.0769 - accuracy: 0.9834 - mean_io_u: 0.7486 - dice_coef: 0.2758 - precision: 0.9839 - sensitivity: 0.9816 - specificity: 0.9946 - dice_coef_necrotic: 0.0810 - dice_coef_edema: 0.1471 - dice_coef_enhancing: 0.0592 - val_loss: 0.1180 - val_accuracy: 0.9820 - val_mean_io_u: 0.5899 - val_dice_coef: 0.2565 - val_precision: 0.9820 - val_sensitivity: 0.9820 - val_specificity: 0.9940 - val_dice_coef_necrotic: 0.0115 - val_dice_coef_edema: 0.0379 - val_dice_coef_enhancing: 0.0016 - lr: 0.0010
# Epoch 3/35
# 249/249 [==============================] - 240s 965ms/step - loss: 0.0720 - accuracy: 0.9833 - mean_io_u: 0.7250 - dice_coef: 0.2772 - precision: 0.9839 - sensitivity: 0.9812 - specificity: 0.9946 - dice_coef_necrotic: 0.0763 - dice_coef_edema: 0.1498 - dice_coef_enhancing: 0.0617 - val_loss: 0.0714 - val_accuracy: 0.9820 - val_mean_io_u: 0.6091 - val_dice_coef: 0.2759 - val_precision: 0.9819 - val_sensitivity: 0.9820 - val_specificity: 0.9940 - val_dice_coef_necrotic: 0.0458 - val_dice_coef_edema: 0.1159 - val_dice_coef_enhancing: 0.0666 - lr: 0.0010
# Epoch 4/35
# 249/249 [==============================] - 241s 969ms/step - loss: 0.0655 - accuracy: 0.9833 - mean_io_u: 0.7420 - dice_coef: 0.2875 - precision: 0.9837 - sensitivity: 0.9826 - specificity: 0.9946 - dice_coef_necrotic: 0.0905 - dice_coef_edema: 0.1629 - dice_coef_enhancing: 0.1044 - val_loss: 0.0654 - val_accuracy: 0.9820 - val_mean_io_u: 0.7403 - val_dice_coef: 0.2934 - val_precision: 0.9820 - val_sensitivity: 0.9819 - val_specificity: 0.9940 - val_dice_coef_necrotic: 0.0939 - val_dice_coef_edema: 0.1561 - val_dice_coef_enhancing: 0.1643 - lr: 0.0010
# Epoch 5/35
# 249/249 [==============================] - 242s 969ms/step - loss: 0.0637 - accuracy: 0.9835 - mean_io_u: 0.7132 - dice_coef: 0.2975 - precision: 0.9843 - sensitivity: 0.9827 - specificity: 0.9948 - dice_coef_necrotic: 0.1073 - dice_coef_edema: 0.1718 - dice_coef_enhancing: 0.1534 - val_loss: 0.0836 - val_accuracy: 0.9827 - val_mean_io_u: 0.3814 - val_dice_coef: 0.3039 - val_precision: 0.9882 - val_sensitivity: 0.9700 - val_specificity: 0.9960 - val_dice_coef_necrotic: 0.1526 - val_dice_coef_edema: 0.2585 - val_dice_coef_enhancing: 0.2258 - lr: 0.0010
# Epoch 6/35
# 249/249 [==============================] - 232s 931ms/step - loss: 0.0620 - accuracy: 0.9828 - mean_io_u: 0.7110 - dice_coef: 0.3110 - precision: 0.9851 - sensitivity: 0.9801 - specificity: 0.9950 - dice_coef_necrotic: 0.1400 - dice_coef_edema: 0.2099 - dice_coef_enhancing: 0.1852 - val_loss: 0.0652 - val_accuracy: 0.9820 - val_mean_io_u: 0.5325 - val_dice_coef: 0.3059 - val_precision: 0.9826 - val_sensitivity: 0.9817 - val_specificity: 0.9943 - val_dice_coef_necrotic: 0.1386 - val_dice_coef_edema: 0.1961 - val_dice_coef_enhancing: 0.2662 - lr: 0.0010
# Epoch 7/35
# 249/249 [==============================] - 233s 934ms/step - loss: 0.0575 - accuracy: 0.9832 - mean_io_u: 0.6369 - dice_coef: 0.3300 - precision: 0.9864 - sensitivity: 0.9814 - specificity: 0.9955 - dice_coef_necrotic: 0.1630 - dice_coef_edema: 0.2338 - dice_coef_enhancing: 0.2553 - val_loss: 0.0690 - val_accuracy: 0.9837 - val_mean_io_u: 0.5427 - val_dice_coef: 0.3248 - val_precision: 0.9911 - val_sensitivity: 0.9765 - val_specificity: 0.9970 - val_dice_coef_necrotic: 0.1944 - val_dice_coef_edema: 0.3365 - val_dice_coef_enhancing: 0.3068 - lr: 0.0010
# Epoch 8/35
# 249/249 [==============================] - 255s 1s/step - loss: 0.0565 - accuracy: 0.9840 - mean_io_u: 0.6960 - dice_coef: 0.3400 - precision: 0.9873 - sensitivity: 0.9815 - specificity: 0.9957 - dice_coef_necrotic: 0.1791 - dice_coef_edema: 0.2629 - dice_coef_enhancing: 0.2890 - val_loss: 0.0553 - val_accuracy: 0.9826 - val_mean_io_u: 0.8054 - val_dice_coef: 0.3359 - val_precision: 0.9855 - val_sensitivity: 0.9812 - val_specificity: 0.9952 - val_dice_coef_necrotic: 0.1583 - val_dice_coef_edema: 0.2809 - val_dice_coef_enhancing: 0.2701 - lr: 0.0010
# Epoch 9/35
# 249/249 [==============================] - 236s 949ms/step - loss: 0.0541 - accuracy: 0.9848 - mean_io_u: 0.5932 - dice_coef: 0.3578 - precision: 0.9887 - sensitivity: 0.9813 - specificity: 0.9962 - dice_coef_necrotic: 0.2124 - dice_coef_edema: 0.2980 - dice_coef_enhancing: 0.3234 - val_loss: 0.0578 - val_accuracy: 0.9829 - val_mean_io_u: 0.7553 - val_dice_coef: 0.3532 - val_precision: 0.9847 - val_sensitivity: 0.9823 - val_specificity: 0.9949 - val_dice_coef_necrotic: 0.1390 - val_dice_coef_edema: 0.2095 - val_dice_coef_enhancing: 0.3565 - lr: 0.0010
# Epoch 10/35
# 249/249 [==============================] - 233s 935ms/step - loss: 0.0477 - accuracy: 0.9863 - mean_io_u: 0.6994 - dice_coef: 0.3877 - precision: 0.9900 - sensitivity: 0.9828 - specificity: 0.9966 - dice_coef_necrotic: 0.2187 - dice_coef_edema: 0.3693 - dice_coef_enhancing: 0.4152 - val_loss: 0.0514 - val_accuracy: 0.9845 - val_mean_io_u: 0.8294 - val_dice_coef: 0.3756 - val_precision: 0.9862 - val_sensitivity: 0.9831 - val_specificity: 0.9954 - val_dice_coef_necrotic: 0.1661 - val_dice_coef_edema: 0.2686 - val_dice_coef_enhancing: 0.4124 - lr: 0.0010
# Epoch 11/35
# 249/249 [==============================] - 271s 1s/step - loss: 0.0433 - accuracy: 0.9870 - mean_io_u: 0.8008 - dice_coef: 0.4170 - precision: 0.9900 - sensitivity: 0.9840 - specificity: 0.9966 - dice_coef_necrotic: 0.2521 - dice_coef_edema: 0.4225 - dice_coef_enhancing: 0.4701 - val_loss: 0.0539 - val_accuracy: 0.9837 - val_mean_io_u: 0.8258 - val_dice_coef: 0.4274 - val_precision: 0.9883 - val_sensitivity: 0.9787 - val_specificity: 0.9961 - val_dice_coef_necrotic: 0.2878 - val_dice_coef_edema: 0.5137 - val_dice_coef_enhancing: 0.5152 - lr: 0.0010
# Epoch 12/35
# 249/249 [==============================] - 242s 966ms/step - loss: 0.0378 - accuracy: 0.9880 - mean_io_u: 0.8182 - dice_coef: 0.4463 - precision: 0.9907 - sensitivity: 0.9853 - specificity: 0.9968 - dice_coef_necrotic: 0.2987 - dice_coef_edema: 0.4666 - dice_coef_enhancing: 0.5301 - val_loss: 0.0406 - val_accuracy: 0.9873 - val_mean_io_u: 0.8185 - val_dice_coef: 0.4421 - val_precision: 0.9907 - val_sensitivity: 0.9835 - val_specificity: 0.9968 - val_dice_coef_necrotic: 0.2554 - val_dice_coef_edema: 0.4664 - val_dice_coef_enhancing: 0.5606 - lr: 0.0010
# Epoch 13/35
# 249/249 [==============================] - 234s 938ms/step - loss: 0.0387 - accuracy: 0.9882 - mean_io_u: 0.8085 - dice_coef: 0.4394 - precision: 0.9910 - sensitivity: 0.9853 - specificity: 0.9969 - dice_coef_necrotic: 0.2979 - dice_coef_edema: 0.4878 - dice_coef_enhancing: 0.4857 - val_loss: 0.0420 - val_accuracy: 0.9869 - val_mean_io_u: 0.7797 - val_dice_coef: 0.4434 - val_precision: 0.9900 - val_sensitivity: 0.9840 - val_specificity: 0.9966 - val_dice_coef_necrotic: 0.2866 - val_dice_coef_edema: 0.4408 - val_dice_coef_enhancing: 0.4916 - lr: 0.0010
# Epoch 14/35
# 249/249 [==============================] - ETA: 0s - loss: 0.0371 - accuracy: 0.9885 - mean_io_u: 0.7966 - dice_coef: 0.4624 - precision: 0.9912 - sensitivity: 0.9856 - specificity: 0.9970 - dice_coef_necrotic: 0.3445 - dice_coef_edema: 0.4935 - dice_coef_enhancing: 0.5566
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 249/249 [==============================] - 237s 952ms/step - loss: 0.0371 - accuracy: 0.9885 - mean_io_u: 0.7966 - dice_coef: 0.4624 - precision: 0.9912 - sensitivity: 0.9856 - specificity: 0.9970 - dice_coef_necrotic: 0.3445 - dice_coef_edema: 0.4935 - dice_coef_enhancing: 0.5566 - val_loss: 0.0408 - val_accuracy: 0.9870 - val_mean_io_u: 0.7932 - val_dice_coef: 0.4516 - val_precision: 0.9883 - val_sensitivity: 0.9858 - val_specificity: 0.9961 - val_dice_coef_necrotic: 0.2218 - val_dice_coef_edema: 0.4868 - val_dice_coef_enhancing: 0.4446 - lr: 0.0010
# Epoch 15/35
# 249/249 [==============================] - 243s 977ms/step - loss: 0.0293 - accuracy: 0.9903 - mean_io_u: 0.7840 - dice_coef: 0.5040 - precision: 0.9923 - sensitivity: 0.9878 - specificity: 0.9974 - dice_coef_necrotic: 0.3890 - dice_coef_edema: 0.5845 - dice_coef_enhancing: 0.6082 - val_loss: 0.0310 - val_accuracy: 0.9900 - val_mean_io_u: 0.7510 - val_dice_coef: 0.5208 - val_precision: 0.9917 - val_sensitivity: 0.9876 - val_specificity: 0.9972 - val_dice_coef_necrotic: 0.3982 - val_dice_coef_edema: 0.6124 - val_dice_coef_enhancing: 0.6269 - lr: 2.0000e-04
# Epoch 16/35
# 249/249 [==============================] - 241s 965ms/step - loss: 0.0265 - accuracy: 0.9911 - mean_io_u: 0.7672 - dice_coef: 0.5323 - precision: 0.9928 - sensitivity: 0.9888 - specificity: 0.9975 - dice_coef_necrotic: 0.4561 - dice_coef_edema: 0.6213 - dice_coef_enhancing: 0.6324 - val_loss: 0.0297 - val_accuracy: 0.9903 - val_mean_io_u: 0.7847 - val_dice_coef: 0.5344 - val_precision: 0.9919 - val_sensitivity: 0.9880 - val_specificity: 0.9972 - val_dice_coef_necrotic: 0.4452 - val_dice_coef_edema: 0.6196 - val_dice_coef_enhancing: 0.6230 - lr: 2.0000e-04
# Epoch 17/35
# 249/249 [==============================] - 270s 1s/step - loss: 0.0252 - accuracy: 0.9914 - mean_io_u: 0.7903 - dice_coef: 0.5469 - precision: 0.9929 - sensitivity: 0.9893 - specificity: 0.9976 - dice_coef_necrotic: 0.4912 - dice_coef_edema: 0.6364 - dice_coef_enhancing: 0.6347 - val_loss: 0.0285 - val_accuracy: 0.9908 - val_mean_io_u: 0.7765 - val_dice_coef: 0.5436 - val_precision: 0.9925 - val_sensitivity: 0.9883 - val_specificity: 0.9974 - val_dice_coef_necrotic: 0.4751 - val_dice_coef_edema: 0.6372 - val_dice_coef_enhancing: 0.6454 - lr: 2.0000e-04
# Epoch 18/35
# 249/249 [==============================] - 235s 944ms/step - loss: 0.0239 - accuracy: 0.9917 - mean_io_u: 0.8070 - dice_coef: 0.5600 - precision: 0.9931 - sensitivity: 0.9896 - specificity: 0.9977 - dice_coef_necrotic: 0.5148 - dice_coef_edema: 0.6544 - dice_coef_enhancing: 0.6433 - val_loss: 0.0291 - val_accuracy: 0.9908 - val_mean_io_u: 0.8138 - val_dice_coef: 0.5476 - val_precision: 0.9925 - val_sensitivity: 0.9884 - val_specificity: 0.9974 - val_dice_coef_necrotic: 0.4938 - val_dice_coef_edema: 0.6235 - val_dice_coef_enhancing: 0.6493 - lr: 2.0000e-04
# Epoch 19/35
# 249/249 [==============================] - 238s 954ms/step - loss: 0.0228 - accuracy: 0.9921 - mean_io_u: 0.8137 - dice_coef: 0.5681 - precision: 0.9933 - sensitivity: 0.9901 - specificity: 0.9977 - dice_coef_necrotic: 0.5360 - dice_coef_edema: 0.6679 - dice_coef_enhancing: 0.6435 - val_loss: 0.0277 - val_accuracy: 0.9912 - val_mean_io_u: 0.8212 - val_dice_coef: 0.5667 - val_precision: 0.9925 - val_sensitivity: 0.9889 - val_specificity: 0.9974 - val_dice_coef_necrotic: 0.5155 - val_dice_coef_edema: 0.6779 - val_dice_coef_enhancing: 0.6495 - lr: 2.0000e-04
# Epoch 20/35
# 249/249 [==============================] - 242s 969ms/step - loss: 0.0222 - accuracy: 0.9923 - mean_io_u: 0.8189 - dice_coef: 0.5777 - precision: 0.9935 - sensitivity: 0.9904 - specificity: 0.9978 - dice_coef_necrotic: 0.5508 - dice_coef_edema: 0.6797 - dice_coef_enhancing: 0.6498 - val_loss: 0.0265 - val_accuracy: 0.9916 - val_mean_io_u: 0.8209 - val_dice_coef: 0.5771 - val_precision: 0.9929 - val_sensitivity: 0.9893 - val_specificity: 0.9976 - val_dice_coef_necrotic: 0.5365 - val_dice_coef_edema: 0.6627 - val_dice_coef_enhancing: 0.6736 - lr: 2.0000e-04
# Epoch 21/35
# 249/249 [==============================] - 239s 957ms/step - loss: 0.0216 - accuracy: 0.9925 - mean_io_u: 0.8254 - dice_coef: 0.5862 - precision: 0.9935 - sensitivity: 0.9906 - specificity: 0.9978 - dice_coef_necrotic: 0.5585 - dice_coef_edema: 0.6880 - dice_coef_enhancing: 0.6587 - val_loss: 0.0274 - val_accuracy: 0.9915 - val_mean_io_u: 0.8266 - val_dice_coef: 0.5779 - val_precision: 0.9926 - val_sensitivity: 0.9895 - val_specificity: 0.9975 - val_dice_coef_necrotic: 0.5325 - val_dice_coef_edema: 0.6607 - val_dice_coef_enhancing: 0.6613 - lr: 2.0000e-04
# Epoch 22/35
# 249/249 [==============================] - ETA: 0s - loss: 0.0207 - accuracy: 0.9928 - mean_io_u: 0.8225 - dice_coef: 0.5938 - precision: 0.9937 - sensitivity: 0.9909 - specificity: 0.9979 - dice_coef_necrotic: 0.5834 - dice_coef_edema: 0.6971 - dice_coef_enhancing: 0.6624
# Epoch 22: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 249/249 [==============================] - 247s 990ms/step - loss: 0.0207 - accuracy: 0.9928 - mean_io_u: 0.8225 - dice_coef: 0.5938 - precision: 0.9937 - sensitivity: 0.9909 - specificity: 0.9979 - dice_coef_necrotic: 0.5834 - dice_coef_edema: 0.6971 - dice_coef_enhancing: 0.6624 - val_loss: 0.0267 - val_accuracy: 0.9918 - val_mean_io_u: 0.8208 - val_dice_coef: 0.5980 - val_precision: 0.9925 - val_sensitivity: 0.9901 - val_specificity: 0.9975 - val_dice_coef_necrotic: 0.5554 - val_dice_coef_edema: 0.6852 - val_dice_coef_enhancing: 0.6668 - lr: 2.0000e-04
# Epoch 23/35
# 249/249 [==============================] - 248s 996ms/step - loss: 0.0191 - accuracy: 0.9933 - mean_io_u: 0.8243 - dice_coef: 0.6125 - precision: 0.9940 - sensitivity: 0.9916 - specificity: 0.9980 - dice_coef_necrotic: 0.6076 - dice_coef_edema: 0.7221 - dice_coef_enhancing: 0.6742 - val_loss: 0.0260 - val_accuracy: 0.9919 - val_mean_io_u: 0.8259 - val_dice_coef: 0.5996 - val_precision: 0.9926 - val_sensitivity: 0.9903 - val_specificity: 0.9975 - val_dice_coef_necrotic: 0.5496 - val_dice_coef_edema: 0.6939 - val_dice_coef_enhancing: 0.6720 - lr: 4.0000e-05
# Epoch 24/35
# 249/249 [==============================] - 242s 971ms/step - loss: 0.0187 - accuracy: 0.9934 - mean_io_u: 0.8273 - dice_coef: 0.6158 - precision: 0.9941 - sensitivity: 0.9917 - specificity: 0.9980 - dice_coef_necrotic: 0.6122 - dice_coef_edema: 0.7273 - dice_coef_enhancing: 0.6788 - val_loss: 0.0262 - val_accuracy: 0.9921 - val_mean_io_u: 0.8279 - val_dice_coef: 0.6033 - val_precision: 0.9928 - val_sensitivity: 0.9904 - val_specificity: 0.9976 - val_dice_coef_necrotic: 0.5597 - val_dice_coef_edema: 0.6889 - val_dice_coef_enhancing: 0.6736 - lr: 4.0000e-05
# Epoch 25/35
# 249/249 [==============================] - ETA: 0s - loss: 0.0184 - accuracy: 0.9935 - mean_io_u: 0.8284 - dice_coef: 0.6190 - precision: 0.9942 - sensitivity: 0.9918 - specificity: 0.9980 - dice_coef_necrotic: 0.6175 - dice_coef_edema: 0.7301 - dice_coef_enhancing: 0.6822
# Epoch 25: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 249/249 [==============================] - 243s 973ms/step - loss: 0.0184 - accuracy: 0.9935 - mean_io_u: 0.8284 - dice_coef: 0.6190 - precision: 0.9942 - sensitivity: 0.9918 - specificity: 0.9980 - dice_coef_necrotic: 0.6175 - dice_coef_edema: 0.7301 - dice_coef_enhancing: 0.6822 - val_loss: 0.0266 - val_accuracy: 0.9921 - val_mean_io_u: 0.8290 - val_dice_coef: 0.6053 - val_precision: 0.9928 - val_sensitivity: 0.9904 - val_specificity: 0.9976 - val_dice_coef_necrotic: 0.5644 - val_dice_coef_edema: 0.6885 - val_dice_coef_enhancing: 0.6716 - lr: 4.0000e-05
# Epoch 26/35
# 249/249 [==============================] - 241s 968ms/step - loss: 0.0181 - accuracy: 0.9936 - mean_io_u: 0.8296 - dice_coef: 0.6228 - precision: 0.9942 - sensitivity: 0.9920 - specificity: 0.9980 - dice_coef_necrotic: 0.6245 - dice_coef_edema: 0.7342 - dice_coef_enhancing: 0.6795 - val_loss: 0.0261 - val_accuracy: 0.9921 - val_mean_io_u: 0.8281 - val_dice_coef: 0.6064 - val_precision: 0.9928 - val_sensitivity: 0.9905 - val_specificity: 0.9976 - val_dice_coef_necrotic: 0.5633 - val_dice_coef_edema: 0.6952 - val_dice_coef_enhancing: 0.6729 - lr: 8.0000e-06
# Epoch 27/35
# 249/249 [==============================] - ETA: 0s - loss: 0.0180 - accuracy: 0.9936 - mean_io_u: 0.8294 - dice_coef: 0.6240 - precision: 0.9942 - sensitivity: 0.9920 - specificity: 0.9980 - dice_coef_necrotic: 0.6247 - dice_coef_edema: 0.7383 - dice_coef_enhancing: 0.6805
# Epoch 27: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 249/249 [==============================] - 241s 967ms/step - loss: 0.0180 - accuracy: 0.9936 - mean_io_u: 0.8294 - dice_coef: 0.6240 - precision: 0.9942 - sensitivity: 0.9920 - specificity: 0.9980 - dice_coef_necrotic: 0.6247 - dice_coef_edema: 0.7383 - dice_coef_enhancing: 0.6805 - val_loss: 0.0260 - val_accuracy: 0.9921 - val_mean_io_u: 0.8275 - val_dice_coef: 0.6062 - val_precision: 0.9928 - val_sensitivity: 0.9905 - val_specificity: 0.9976 - val_dice_coef_necrotic: 0.5632 - val_dice_coef_edema: 0.6960 - val_dice_coef_enhancing: 0.6761 - lr: 8.0000e-06
# Epoch 28/35
# 249/249 [==============================] - 240s 966ms/step - loss: 0.0179 - accuracy: 0.9937 - mean_io_u: 0.8288 - dice_coef: 0.6236 - precision: 0.9943 - sensitivity: 0.9920 - specificity: 0.9981 - dice_coef_necrotic: 0.6243 - dice_coef_edema: 0.7375 - dice_coef_enhancing: 0.6823 - val_loss: 0.0259 - val_accuracy: 0.9921 - val_mean_io_u: 0.8275 - val_dice_coef: 0.6066 - val_precision: 0.9928 - val_sensitivity: 0.9905 - val_specificity: 0.9976 - val_dice_coef_necrotic: 0.5638 - val_dice_coef_edema: 0.6972 - val_dice_coef_enhancing: 0.6771 - lr: 1.6000e-06
# Epoch 29/35
# 249/249 [==============================] - ETA: 0s - loss: 0.0179 - accuracy: 0.9937 - mean_io_u: 0.8288 - dice_coef: 0.6238 - precision: 0.9943 - sensitivity: 0.9920 - specificity: 0.9981 - dice_coef_necrotic: 0.6250 - dice_coef_edema: 0.7382 - dice_coef_enhancing: 0.6828
# Epoch 29: ReduceLROnPlateau reducing learning rate to 1e-06.
# 249/249 [==============================] - 240s 962ms/step - loss: 0.0179 - accuracy: 0.9937 - mean_io_u: 0.8288 - dice_coef: 0.6238 - precision: 0.9943 - sensitivity: 0.9920 - specificity: 0.9981 - dice_coef_necrotic: 0.6250 - dice_coef_edema: 0.7382 - dice_coef_enhancing: 0.6828 - val_loss: 0.0260 - val_accuracy: 0.9921 - val_mean_io_u: 0.8277 - val_dice_coef: 0.6069 - val_precision: 0.9928 - val_sensitivity: 0.9905 - val_specificity: 0.9976 - val_dice_coef_necrotic: 0.5641 - val_dice_coef_edema: 0.6971 - val_dice_coef_enhancing: 0.6770 - lr: 1.6000e-06
# Epoch 30/35
# 249/249 [==============================] - 248s 996ms/step - loss: 0.0179 - accuracy: 0.9937 - mean_io_u: 0.8290 - dice_coef: 0.6243 - precision: 0.9943 - sensitivity: 0.9920 - specificity: 0.9981 - dice_coef_necrotic: 0.6251 - dice_coef_edema: 0.7386 - dice_coef_enhancing: 0.6827 - val_loss: 0.0260 - val_accuracy: 0.9921 - val_mean_io_u: 0.8277 - val_dice_coef: 0.6071 - val_precision: 0.9928 - val_sensitivity: 0.9905 - val_specificity: 0.9976 - val_dice_coef_necrotic: 0.5643 - val_dice_coef_edema: 0.6975 - val_dice_coef_enhancing: 0.6773 - lr: 1.0000e-06
# Epoch 31/35
# 249/249 [==============================] - 275s 1s/step - loss: 0.0178 - accuracy: 0.9937 - mean_io_u: 0.8290 - dice_coef: 0.6244 - precision: 0.9943 - sensitivity: 0.9920 - specificity: 0.9981 - dice_coef_necrotic: 0.6254 - dice_coef_edema: 0.7390 - dice_coef_enhancing: 0.6829 - val_loss: 0.0260 - val_accuracy: 0.9921 - val_mean_io_u: 0.8278 - val_dice_coef: 0.6071 - val_precision: 0.9928 - val_sensitivity: 0.9905 - val_specificity: 0.9976 - val_dice_coef_necrotic: 0.5645 - val_dice_coef_edema: 0.6974 - val_dice_coef_enhancing: 0.6775 - lr: 1.0000e-06
# Epoch 32/35
# 249/249 [==============================] - 237s 950ms/step - loss: 0.0178 - accuracy: 0.9937 - mean_io_u: 0.8290 - dice_coef: 0.6244 - precision: 0.9943 - sensitivity: 0.9920 - specificity: 0.9981 - dice_coef_necrotic: 0.6255 - dice_coef_edema: 0.7389 - dice_coef_enhancing: 0.6831 - val_loss: 0.0260 - val_accuracy: 0.9921 - val_mean_io_u: 0.8278 - val_dice_coef: 0.6072 - val_precision: 0.9928 - val_sensitivity: 0.9905 - val_specificity: 0.9976 - val_dice_coef_necrotic: 0.5647 - val_dice_coef_edema: 0.6973 - val_dice_coef_enhancing: 0.6777 - lr: 1.0000e-06
# Epoch 33/35
# 249/249 [==============================] - 238s 955ms/step - loss: 0.0178 - accuracy: 0.9937 - mean_io_u: 0.8291 - dice_coef: 0.6246 - precision: 0.9943 - sensitivity: 0.9920 - specificity: 0.9981 - dice_coef_necrotic: 0.6260 - dice_coef_edema: 0.7388 - dice_coef_enhancing: 0.6834 - val_loss: 0.0260 - val_accuracy: 0.9921 - val_mean_io_u: 0.8278 - val_dice_coef: 0.6074 - val_precision: 0.9928 - val_sensitivity: 0.9905 - val_specificity: 0.9976 - val_dice_coef_necrotic: 0.5647 - val_dice_coef_edema: 0.6972 - val_dice_coef_enhancing: 0.6777 - lr: 1.0000e-06
# Epoch 34/35
# 249/249 [==============================] - 236s 949ms/step - loss: 0.0178 - accuracy: 0.9937 - mean_io_u: 0.8292 - dice_coef: 0.6249 - precision: 0.9943 - sensitivity: 0.9920 - specificity: 0.9981 - dice_coef_necrotic: 0.6262 - dice_coef_edema: 0.7392 - dice_coef_enhancing: 0.6830 - val_loss: 0.0260 - val_accuracy: 0.9921 - val_mean_io_u: 0.8279 - val_dice_coef: 0.6075 - val_precision: 0.9928 - val_sensitivity: 0.9905 - val_specificity: 0.9976 - val_dice_coef_necrotic: 0.5647 - val_dice_coef_edema: 0.6971 - val_dice_coef_enhancing: 0.6777 - lr: 1.0000e-06
# Epoch 35/35
# 249/249 [==============================] - 242s 973ms/step - loss: 0.0178 - accuracy: 0.9937 - mean_io_u: 0.8293 - dice_coef: 0.6251 - precision: 0.9943 - sensitivity: 0.9921 - specificity: 0.9981 - dice_coef_necrotic: 0.6263 - dice_coef_edema: 0.7392 - dice_coef_enhancing: 0.6830 - val_loss: 0.0260 - val_accuracy: 0.9921 - val_mean_io_u: 0.8279 - val_dice_coef: 0.6076 - val_precision: 0.9928 - val_sensitivity: 0.9905 - val_specificity: 0.9976 - val_dice_coef_necrotic: 0.5649 - val_dice_coef_edema: 0.6975 - val_dice_coef_enhancing: 0.6780 - lr: 1.0000e-06

# %%
############ load trained model ################
model = keras.models.load_model('/kaggle/working/model_run3.h5', 
                                   custom_objects={ 'accuracy' : tf.keras.metrics.MeanIoU(num_classes=4),
                                                   "dice_coef": dice_coef,
                                                   "precision": precision,
                                                   "sensitivity":sensitivity,
                                                   "specificity":specificity,
                                                   "dice_coef_necrotic": dice_coef_necrotic,
                                                   "dice_coef_edema": dice_coef_edema,
                                                   "dice_coef_enhancing": dice_coef_enhancing
                                                  }, compile=False)

history = pd.read_csv('/kaggle/working/training3.log', sep=',', engine='python')

hist=history

############### ########## ####### #######

# hist=history.history

acc=hist['accuracy']
val_acc=hist['val_accuracy']

epoch=range(len(acc))

loss=hist['loss']
val_loss=hist['val_loss']

train_dice=hist['dice_coef']
val_dice=hist['val_dice_coef']

f,ax=plt.subplots(1,4,figsize=(16,8))

ax[0].plot(epoch,acc,'b',label='Training Accuracy')
ax[0].plot(epoch,val_acc,'r',label='Validation Accuracy')
ax[0].legend()

ax[1].plot(epoch,loss,'b',label='Training Loss')
ax[1].plot(epoch,val_loss,'r',label='Validation Loss')
ax[1].legend()

ax[2].plot(epoch,train_dice,'b',label='Training dice coef')
ax[2].plot(epoch,val_dice,'r',label='Validation dice coef')
ax[2].legend()

ax[3].plot(epoch,hist['mean_io_u'],'b',label='Training mean IOU')
ax[3].plot(epoch,hist['val_mean_io_u'],'r',label='Validation mean IOU')
ax[3].legend()

plt.show()

# %%
# mri type must one of 1) flair 2) t1 3) t1ce 4) t2 ------- or even 5) seg
# returns volume of specified study at `path`
def imageLoader(path):
    image = nib.load(path).get_fdata()
    X = np.zeros((self.batch_size*VOLUME_SLICES, *self.dim, self.n_channels))
    for j in range(VOLUME_SLICES):
        X[j +VOLUME_SLICES*c,:,:,0] = cv2.resize(image[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE));
        X[j +VOLUME_SLICES*c,:,:,1] = cv2.resize(ce[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE));

        y[j +VOLUME_SLICES*c] = seg[:,:,j+VOLUME_START_AT];
    return np.array(image)


# load nifti file at `path`
# and load each slice with mask from volume
# choose the mri type & resize to `IMG_SIZE`
def loadDataFromDir(path, list_of_files, mriType, n_images):
    scans = []
    masks = []
    for i in list_of_files[:n_images]:
        fullPath = glob.glob( i + '/*'+ mriType +'*')[0]
        currentScanVolume = imageLoader(fullPath)
        currentMaskVolume = imageLoader( glob.glob( i + '/*seg*')[0] ) 
        # for each slice in 3D volume, find also it's mask
        for j in range(0, currentScanVolume.shape[2]):
            scan_img = cv2.resize(currentScanVolume[:,:,j], dsize=(IMG_SIZE,IMG_SIZE), interpolation=cv2.INTER_AREA).astype('uint8')
            mask_img = cv2.resize(currentMaskVolume[:,:,j], dsize=(IMG_SIZE,IMG_SIZE), interpolation=cv2.INTER_AREA).astype('uint8')
            scans.append(scan_img[..., np.newaxis])
            masks.append(mask_img[..., np.newaxis])
    return np.array(scans, dtype='float32'), np.array(masks, dtype='float32')
        
#brains_list_test, masks_list_test = loadDataFromDir(VALIDATION_DATASET_PATH, test_directories, "flair", 5)

# %%
def predictByPath(case_path,case):
    files = next(os.walk(case_path))[2]
    X = np.empty((VOLUME_SLICES, IMG_SIZE, IMG_SIZE, 2))
  #  y = np.empty((VOLUME_SLICES, IMG_SIZE, IMG_SIZE))
    
    vol_path = os.path.join(case_path, f'BraTS20_Training_{case}_flair.nii');
    flair=nib.load(vol_path).get_fdata()
    
    vol_path = os.path.join(case_path, f'BraTS20_Training_{case}_t1ce.nii');
    ce=nib.load(vol_path).get_fdata() 
    
 #   vol_path = os.path.join(case_path, f'BraTS20_Training_{case}_seg.nii');
 #   seg=nib.load(vol_path).get_fdata()  

    
    for j in range(VOLUME_SLICES):
        X[j,:,:,0] = cv2.resize(flair[:,:,j+VOLUME_START_AT], (IMG_SIZE,IMG_SIZE))
        X[j,:,:,1] = cv2.resize(ce[:,:,j+VOLUME_START_AT], (IMG_SIZE,IMG_SIZE))
 #       y[j,:,:] = cv2.resize(seg[:,:,j+VOLUME_START_AT], (IMG_SIZE,IMG_SIZE))
        
  #  model.evaluate(x=X,y=y[:,:,:,0], callbacks= callbacks)
    return model.predict(X/np.max(X), verbose=1)


def showPredictsById(case, start_slice = 60):
    path = f"../input/brats20-dataset-training-validation/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_{case}"
    gt = nib.load(os.path.join(path, f'BraTS20_Training_{case}_seg.nii')).get_fdata()
    origImage = nib.load(os.path.join(path, f'BraTS20_Training_{case}_flair.nii')).get_fdata()
    p = predictByPath(path,case)

    core = p[:,:,:,1]
    edema= p[:,:,:,2]
    enhancing = p[:,:,:,3]

    plt.figure(figsize=(18, 50))
    f, axarr = plt.subplots(1,6, figsize = (18, 50)) 

    for i in range(6): # for each image, add brain background
        axarr[i].imshow(cv2.resize(origImage[:,:,start_slice+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE)), cmap="gray", interpolation='none')
    
    axarr[0].imshow(cv2.resize(origImage[:,:,start_slice+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE)), cmap="gray")
    axarr[0].title.set_text('Original image flair')
    curr_gt=cv2.resize(gt[:,:,start_slice+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE), interpolation = cv2.INTER_NEAREST)
    axarr[1].imshow(curr_gt, cmap="Reds", interpolation='none', alpha=0.3) # ,alpha=0.3,cmap='Reds'
    axarr[1].title.set_text('Ground truth')
    axarr[2].imshow(p[start_slice,:,:,1:4], cmap="Reds", interpolation='none', alpha=0.3)
    axarr[2].title.set_text('all classes')
    axarr[3].imshow(edema[start_slice,:,:], cmap="OrRd", interpolation='none', alpha=0.3)
    axarr[3].title.set_text(f'{SEGMENT_CLASSES[1]} predicted')
    axarr[4].imshow(core[start_slice,:,], cmap="OrRd", interpolation='none', alpha=0.3)
    axarr[4].title.set_text(f'{SEGMENT_CLASSES[2]} predicted')
    axarr[5].imshow(enhancing[start_slice,:,], cmap="OrRd", interpolation='none', alpha=0.3)
    axarr[5].title.set_text(f'{SEGMENT_CLASSES[3]} predicted')
    plt.show()
    
    
showPredictsById(case=test_ids[0][-3:])
showPredictsById(case=test_ids[1][-3:])
showPredictsById(case=test_ids[2][-3:])
showPredictsById(case=test_ids[3][-3:])
showPredictsById(case=test_ids[4][-3:])
showPredictsById(case=test_ids[5][-3:])
showPredictsById(case=test_ids[6][-3:])


# mask = np.zeros((10,10))
# mask[3:-3, 3:-3] = 1 # white square in black background
# im = mask + np.random.randn(10,10) * 0.01 # random image
# masked = np.ma.masked_where(mask == 0, mask)

# plt.figure()
# plt.subplot(1,2,1)
# plt.imshow(im, 'gray', interpolation='none')
# plt.subplot(1,2,2)
# plt.imshow(im, 'gray', interpolation='none')
# plt.imshow(masked, 'jet', interpolation='none', alpha=0.7)
# plt.show()
# Out:
# 4/4 [==============================] - 4s 315ms/step
# 4/4 [==============================] - 0s 67ms/step
# 4/4 [==============================] - 0s 46ms/step
# 4/4 [==============================] - 0s 46ms/step
# 4/4 [==============================] - 0s 67ms/step
# 4/4 [==============================] - 0s 47ms/step
# 4/4 [==============================] - 0s 45ms/step

# %%
case = case=test_ids[3][-3:]
path = f"../input/brats20-dataset-training-validation/BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_{case}"
gt = nib.load(os.path.join(path, f'BraTS20_Training_{case}_seg.nii')).get_fdata()
p = predictByPath(path,case)


core = p[:,:,:,1]
edema= p[:,:,:,2]
enhancing = p[:,:,:,3]


i=40 # slice at
eval_class = 2 #     0 : 'NOT tumor',  1 : 'ENHANCING',    2 : 'CORE',    3 : 'WHOLE'



gt[gt != eval_class] = 1 # use only one class for per class evaluation 

resized_gt = cv2.resize(gt[:,:,i+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))

plt.figure()
f, axarr = plt.subplots(1,2) 
axarr[0].imshow(resized_gt, cmap="gray")
axarr[0].title.set_text('ground truth')
axarr[1].imshow(p[i,:,:,eval_class], cmap="gray")
axarr[1].title.set_text(f'predicted class: {SEGMENT_CLASSES[eval_class]}')
plt.show()
# Out:
# 4/4 [==============================] - 0s 67ms/step

# %%
model.compile(loss="categorical_crossentropy", optimizer=keras.optimizers.Adam(learning_rate=0.001), metrics = ['accuracy',tf.keras.metrics.MeanIoU(num_classes=4), dice_coef, precision, sensitivity, specificity, dice_coef_necrotic, dice_coef_edema, dice_coef_enhancing] )
# Evaluate the model on the test data using `evaluate`
print("Evaluate on test data")
results = model.evaluate(test_generator, batch_size=100, callbacks= callbacks)
print("test loss, test acc:", results)
# Out:
# Evaluate on test data
# 45/45 [==============================] - 32s 672ms/step - loss: 0.0215 - accuracy: 0.9927 - mean_io_u_1: 0.8293 - dice_coef: 0.5978 - precision: 0.9933 - sensitivity: 0.9912 - specificity: 0.9978 - dice_coef_necrotic: 0.5347 - dice_coef_edema: 0.6968 - dice_coef_enhancing: 0.6705
# test loss, test acc: [0.021462252363562584, 0.9927107095718384, 0.8293341398239136, 0.5977849364280701, 0.9933411478996277, 0.9912199974060059, 0.9977523684501648, 0.5346898436546326, 0.696837306022644, 0.670452356338501]
